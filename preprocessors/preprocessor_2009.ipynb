# %% [markdown]
# 해당 노트북은 assistment 2009-2010 데이터를 전처리하기 위한 용도로 사용

# %%
import pandas as pd

#2009 skill data 불러오기
skill_data_path = "../datasets/assistment2009_2010/skill_builder_data.csv"

pd_skill = pd.read_csv(skill_data_path, encoding="ISO-8859-1")

pd_skill.head()
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:3072: DtypeWarning: Columns (17) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    order_id  assignment_id  user_id  assistment_id  problem_id  original  \
# 0  33022537         277618    64525          33139       51424         1
# 1  33022709         277618    64525          33150       51435         1
# 2  35450204         220674    70363          33159       51444         1
# 3  35450295         220674    70363          33110       51395         1
# 4  35450311         220674    70363          33196       51481         1
#
#    correct  attempt_count  ms_first_response tutor_mode  ... hint_count  \
# 0        1              1              32454      tutor  ...          0
# 1        1              1               4922      tutor  ...          0
# ...

# %%
pd_skill['skill_name'].unique()
# Out:
# array(['Box and Whisker', 'Circle Graph', 'Histogram as Table or Graph',
#        'Number Line', 'Scatter Plot', 'Stem and Leaf Plot', 'Table',
#        'Venn Diagram', 'Mean', 'Median', 'Mode', 'Range',
#        'Counting Methods', 'Probability of Two Distinct Events',
#        'Probability of a Single Event',
#        'Interior Angles Figures with More than 3 Sides',
#        'Interior Angles Triangle', 'Congruence',
#        'Complementary and Supplementary Angles',
#        'Angles on Parallel Lines Cut by a Transversal',
#        'Pythagorean Theorem', 'Nets of 3D Figures',
#        'Unit Conversion Within a System',
#        'Effect of Changing Dimensions of a Shape Prportionally', nan,
#        'Area Circle', 'Circumference ', 'Perimeter of a Polygon',
#        'Reading a Ruler or Scale', 'Calculations with Similar Figures',
#        'Conversion of Fraction Decimals Percents', 'Equivalent Fractions',
#        'Ordering Positive Decimals', 'Ordering Fractions',
# ...

# %%
pd_skill.describe()
# Out:
#            order_id  assignment_id        user_id  assistment_id  \
# count  5.255340e+05  525534.000000  525534.000000  525534.000000
# mean   3.161965e+07  275517.199675   82623.435437   47937.082410
# std    4.941704e+06   10508.585740    6980.075777   12163.903242
# min    2.022408e+07  217900.000000      14.000000      86.000000
# 25%    2.842936e+07  268669.000000   78558.000000   38069.000000
# 50%    3.287434e+07  276974.000000   79066.000000   47752.000000
# 75%    3.511790e+07  280999.000000   86415.000000   52325.000000
# max    3.831020e+07  291503.000000   96299.000000  106210.000000
#
#           problem_id       original        correct  attempt_count  \
# count  525534.000000  525534.000000  525534.000000  525534.000000
# mean    84113.537240       0.854788       0.679471       1.502466
# std     25818.833052       0.352315       0.466680      10.579588
# min        83.000000       0.000000       0.000000       0.000000
# ...

# %%
#1. 일단 skill_name에서 NaN이 뜨는 행 모두 제거

pd_skill = pd_skill.dropna(subset = ['skill_name'])

# %%
pd_skill.describe()
# Out:
#            order_id  assignment_id        user_id  assistment_id  \
# count  4.468440e+05  446844.000000  446844.000000  446844.000000
# mean   3.174246e+07  275862.066663   82497.623535   47790.094172
# std    4.862266e+06   10099.580519    6933.925745   11552.314348
# min    2.022408e+07  217900.000000      14.000000      86.000000
# 25%    2.867393e+07  269896.000000   78551.000000   39241.000000
# 50%    3.346530e+07  277549.000000   79054.000000   48178.000000
# 75%    3.511823e+07  281001.000000   86325.000000   52076.000000
# max    3.831020e+07  291503.000000   96299.000000  102044.000000
#
#           problem_id       original        correct  attempt_count  \
# count  446844.000000  446844.000000  446844.000000  446844.000000
# mean    83843.750953       0.942875       0.695187       1.450298
# std     24556.023228       0.232082       0.460329      10.724505
# min        83.000000       0.000000       0.000000       0.000000
# ...

# %%
# oportunity가 8 초과인 경우 모두 삭제
